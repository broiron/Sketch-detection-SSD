# %%
import pandas as pd

# %%
df = pd.read_csv('./losses1.csv')

# %%
df['0']
# Out:
# 0       148.955811
# 1       121.521049
# 2        94.428627
# 3        73.601044
# 4        71.657104
#            ...
# 1555      3.898438
# 1556      5.275641
# 1557      4.296820
# 1558      3.584236
# 1559      4.908030
# Name: 0, Length: 1560, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(df['0'])
plt.xlabel('iteration')
plt.ylabel('total_loss')
# Out:
# Text(0, 0.5, 'total_loss')

# %%
df = pd.read_csv('/home/broiron/broiron/model_train/Simple-RFCN-PyTorch/rfcn_1_train_total_loss.csv')

# %%
plt.plot(df['0'])
plt.xlabel('epoch')
plt.ylabel('total_loss')
# Out:
# Text(0, 0.5, 'total_loss')
